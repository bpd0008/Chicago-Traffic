# %%
import scipy.stats as st
from scipy.stats import linregress
import numpy as np
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import seaborn as sns; sns.set()
from matplotlib import pyplot as plt

import pandas as pd
from sodapy import Socrata
from config import CHI_API_Key
# Unauthenticated client only works with public data sets. Note 'None'
# in place of application token, and no username or password:
client = Socrata("data.cityofchicago.org", app_token = CHI_API_Key)
# Example authenticated client (needed for non-public datasets):
# client = Socrata(data.cityofchicago.org,
#                  MyAppToken,
#                  userame="user@example.com",
#                  password="AFakePassword")
# First 2000 results, returned as JSON from API / converted to Python list ofS
# dictionaries by sodapy.
results = client.get("85ca-t3if", limit= 2000)
# Convert to pandas DataFrame
results_df = pd.DataFrame.from_records(results)

# %%
results_df
# Out:
#                                         crash_record_id  \
# 0     7a5aa591c320dcaa50ee5ff9d0eedb9e423a1f1efa1e4c...
# 1     d95b7c167abad30dff8f1eb4a4f96dabe098eeb9c18d4b...
# 2     a4b8ed2784f7e2f23339aec7b3480aa27c300a77629a44...
# 3     d93027425fc325efbeb74de500f9cee5ef1ab4b177fc5d...
# 4     db0c556175dbae5d290139b69d461480dcdcc3003b8cdd...
# ...                                                 ...
# 1995  6a04c9d28679ca0d0a46433b13f2d56d17dfe494ff1d76...
# 1996  84ab7d75100ed131c587bc98fdc473a7ade2257a9c9bb5...
# 1997  92bf7440a7ee3b4ab76736ab33e9917a61aa39e9f89c39...
# 1998  d8481445cafd272438c252b9a110efa6f538fdd416cb63...
# 1999  e46b559ddfe47c61ab14bd7ff0161c3977122cdffd8b0d...
#
#                    crash_date posted_speed_limit traffic_control_device  \
# 0     2020-11-14T02:10:00.000                 30            NO CONTROLS
# 1     2020-11-14T01:55:00.000                 30            NO CONTROLS
# 2     2020-11-14T01:26:00.000                 30            NO CONTROLS
# 3     2020-11-14T00:53:00.000                 30         TRAFFIC SIGNAL
# 4     2020-11-14T00:48:00.000                 35         TRAFFIC SIGNAL
# ...                       ...                ...                    ...
# 1995  2020-11-04T19:28:00.000                 30            NO CONTROLS
# 1996  2020-11-04T19:15:00.000                 30            NO CONTROLS
# 1997  2020-11-04T19:15:00.000                 30         TRAFFIC SIGNAL
# 1998  2020-11-04T19:14:00.000                 30      STOP SIGN/FLASHER
# 1999  2020-11-04T19:00:00.000                 30            NO CONTROLS
#
#           device_condition weather_condition      lighting_condition  \
# 0              NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 1              NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 2              NO CONTROLS             CLEAR  DARKNESS, LIGHTED ROAD
# 3     FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 4     FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# ...                    ...               ...                     ...
# 1995           NO CONTROLS             CLEAR                DAYLIGHT
# 1996           NO CONTROLS             CLEAR                DARKNESS
# 1997  FUNCTIONING PROPERLY             CLEAR  DARKNESS, LIGHTED ROAD
# 1998                 OTHER             CLEAR  DARKNESS, LIGHTED ROAD
# 1999           NO CONTROLS             CLEAR                    DAWN
#
#           first_crash_type                  trafficway_type  \
# 0     PARKED MOTOR VEHICLE                      NOT DIVIDED
# 1     PARKED MOTOR VEHICLE                          ONE-WAY
# 2     PARKED MOTOR VEHICLE                      NOT DIVIDED
# 3                  TURNING                         FOUR WAY
# 4                    ANGLE        UNKNOWN INTERSECTION TYPE
# ...                    ...                              ...
# 1995              REAR END                      NOT DIVIDED
# 1996  PARKED MOTOR VEHICLE                      NOT DIVIDED
# 1997              REAR END  DIVIDED - W/MEDIAN (NOT RAISED)
# 1998              REAR END                            OTHER
# 1999                 ANGLE                      NOT DIVIDED
#
#                alignment  ... hit_and_run_i intersection_related_i  \
# 0     STRAIGHT AND LEVEL  ...           NaN                    NaN
# 1     STRAIGHT AND LEVEL  ...             Y                    NaN
# 2     STRAIGHT AND LEVEL  ...           NaN                    NaN
# 3     STRAIGHT AND LEVEL  ...           NaN                      Y
# 4     STRAIGHT AND LEVEL  ...           NaN                      Y
# ...                  ...  ...           ...                    ...
# 1995  STRAIGHT AND LEVEL  ...             Y                    NaN
# 1996  STRAIGHT AND LEVEL  ...           NaN                    NaN
# 1997  STRAIGHT AND LEVEL  ...           NaN                    NaN
# 1998  STRAIGHT AND LEVEL  ...             Y                      Y
# 1999  STRAIGHT AND LEVEL  ...           NaN                    NaN
#
#      photos_taken_i statements_taken_i crash_date_est_i private_property_i  \
# 0               NaN                NaN              NaN                NaN
# 1               NaN                NaN              NaN                NaN
# 2               NaN                NaN              NaN                NaN
# 3               NaN                NaN              NaN                NaN
# 4               NaN                NaN              NaN                NaN
# ...             ...                ...              ...                ...
# 1995            NaN                NaN              NaN                NaN
# 1996            NaN                NaN              NaN                NaN
# 1997            NaN                NaN              NaN                NaN
# 1998            NaN                NaN              NaN                NaN
# 1999            NaN                NaN              NaN                NaN
#
#      work_zone_i work_zone_type dooring_i workers_present_i
# 0            NaN            NaN       NaN               NaN
# 1            NaN            NaN       NaN               NaN
# 2            NaN            NaN       NaN               NaN
# 3            NaN            NaN       NaN               NaN
# 4            NaN            NaN       NaN               NaN
# ...          ...            ...       ...               ...
# 1995         NaN            NaN       NaN               NaN
# 1996         NaN            NaN       NaN               NaN
# 1997         NaN            NaN       NaN               NaN
# 1998         NaN            NaN       NaN               NaN
# 1999         NaN            NaN       NaN               NaN
#
# [2000 rows x 47 columns]

# %%
results_df.columns
# Out:
# Index(['crash_record_id', 'crash_date', 'posted_speed_limit',
#        'traffic_control_device', 'device_condition', 'weather_condition',
#        'lighting_condition', 'first_crash_type', 'trafficway_type',
#        'alignment', 'roadway_surface_cond', 'road_defect', 'report_type',
#        'crash_type', 'damage', 'date_police_notified',
#        'prim_contributory_cause', 'sec_contributory_cause', 'street_no',
#        'street_direction', 'street_name', 'beat_of_occurrence', 'num_units',
#        'most_severe_injury', 'injuries_total', 'injuries_fatal',
#        'injuries_incapacitating', 'injuries_non_incapacitating',
#        'injuries_reported_not_evident', 'injuries_no_indication',
#        'injuries_unknown', 'crash_hour', 'crash_day_of_week', 'crash_month',
#        'latitude', 'longitude', 'location', 'hit_and_run_i',
#        'intersection_related_i', 'photos_taken_i', 'statements_taken_i',
#        'crash_date_est_i', 'private_property_i', 'work_zone_i',
#        'work_zone_type', 'dooring_i', 'workers_present_i'],
#       dtype='object')

# %%
results_df.dtypes
# Out:
# crash_record_id                  object
# crash_date                       object
# posted_speed_limit               object
# traffic_control_device           object
# device_condition                 object
# weather_condition                object
# lighting_condition               object
# first_crash_type                 object
# trafficway_type                  object
# alignment                        object
# roadway_surface_cond             object
# road_defect                      object
# report_type                      object
# crash_type                       object
# damage                           object
# date_police_notified             object
# prim_contributory_cause          object
# sec_contributory_cause           object
# street_no                        object
# street_direction                 object
# street_name                      object
# beat_of_occurrence               object
# num_units                        object
# most_severe_injury               object
# injuries_total                   object
# injuries_fatal                   object
# injuries_incapacitating          object
# injuries_non_incapacitating      object
# injuries_reported_not_evident    object
# injuries_no_indication           object
# injuries_unknown                 object
# crash_hour                       object
# crash_day_of_week                object
# crash_month                      object
# latitude                         object
# longitude                        object
# location                         object
# hit_and_run_i                    object
# intersection_related_i           object
# photos_taken_i                   object
# statements_taken_i               object
# crash_date_est_i                 object
# private_property_i               object
# work_zone_i                      object
# work_zone_type                   object
# dooring_i                        object
# workers_present_i                object
# dtype: object

# %%
# Create file with the columns needed
geo_df = pd.DataFrame(results_df[['crash_record_id', 'latitude','longitude', 'crash_month', 'crash_day_of_week', 'crash_hour', 'weather_condition', 'lighting_condition', 'damage', 'crash_type', 'injuries_total', 'posted_speed_limit', 'prim_contributory_cause']])
geo_df.head(10)
# Out:
#                                      crash_record_id      latitude  \
# 0  7a5aa591c320dcaa50ee5ff9d0eedb9e423a1f1efa1e4c...  41.734652174
# 1  d95b7c167abad30dff8f1eb4a4f96dabe098eeb9c18d4b...  41.788311923
# 2  a4b8ed2784f7e2f23339aec7b3480aa27c300a77629a44...  41.764817753
# 3  d93027425fc325efbeb74de500f9cee5ef1ab4b177fc5d...  41.880880323
# 4  db0c556175dbae5d290139b69d461480dcdcc3003b8cdd...  41.699547415
# 5  ba5c3b73f593635bd96dae4e93d2a46b3ecf6414974a0d...   41.80247042
# 6  2ea4960b7f03e1928d7cb50a836bb998a3207ae354f861...  41.896804972
# 7  dd755b68a258cd049b7a63ba3b1cd3938e1a6123851de2...   41.77557861
# 8  07bc8ee01e3b260016d0de2898fab86daa65f1632e85c8...  41.878984407
# 9  36460c408759f2674ee74c9d652973b35c23543f8f518d...  41.817224158
#
#        longitude crash_month crash_day_of_week crash_hour weather_condition  \
# 0  -87.637350523          11                 7          2             CLEAR
# 1  -87.671862047          11                 7          1             CLEAR
# 2  -87.662458484          11                 7          1             CLEAR
# 3  -87.666940386          11                 7          0             CLEAR
# 4  -87.642751915          11                 7          0             CLEAR
# 5  -87.581777928          11                 6         23           UNKNOWN
# 6  -87.617027423          11                 6         22             CLEAR
# 7  -87.675171024          11                 6         22             CLEAR
# 8  -87.725183053          11                 6         20             CLEAR
# 9  -87.624526546          11                 6         20             CLEAR
#
#        lighting_condition        damage                        crash_type  \
# 0  DARKNESS, LIGHTED ROAD  $500 OR LESS            NO INJURY / DRIVE AWAY
# 1  DARKNESS, LIGHTED ROAD   OVER $1,500            NO INJURY / DRIVE AWAY
# 2  DARKNESS, LIGHTED ROAD   OVER $1,500            NO INJURY / DRIVE AWAY
# 3  DARKNESS, LIGHTED ROAD   OVER $1,500  INJURY AND / OR TOW DUE TO CRASH
# 4  DARKNESS, LIGHTED ROAD   OVER $1,500            NO INJURY / DRIVE AWAY
# 5                 UNKNOWN   OVER $1,500            NO INJURY / DRIVE AWAY
# 6  DARKNESS, LIGHTED ROAD  $500 OR LESS            NO INJURY / DRIVE AWAY
# 7  DARKNESS, LIGHTED ROAD   OVER $1,500            NO INJURY / DRIVE AWAY
# 8  DARKNESS, LIGHTED ROAD   OVER $1,500  INJURY AND / OR TOW DUE TO CRASH
# 9  DARKNESS, LIGHTED ROAD   OVER $1,500            NO INJURY / DRIVE AWAY
#
#   injuries_total posted_speed_limit             prim_contributory_cause
# 0              0                 30  DISTRACTION - FROM OUTSIDE VEHICLE
# 1              0                 30     DRIVING ON WRONG SIDE/WRONG WAY
# 2              0                 30       EQUIPMENT - VEHICLE CONDITION
# 3            NaN                 30        DISREGARDING TRAFFIC SIGNALS
# 4              0                 35        DISREGARDING TRAFFIC SIGNALS
# 5              0                 30                 UNABLE TO DETERMINE
# 6              0                 35       EQUIPMENT - VEHICLE CONDITION
# 7              0                 30                 UNABLE TO DETERMINE
# 8              0                 25                 UNABLE TO DETERMINE
# 9              0                 30                 IMPROPER LANE USAGE

# %%
geo_df.describe()
# Out:
#                                           crash_record_id      latitude  \
# count                                                2000          1987
# unique                                               2000          1923
# top     b2913d087e90f3878667ce448bcc360bac6b630093a012...  41.851654369
# freq                                                    1             3
#
#             longitude crash_month crash_day_of_week crash_hour  \
# count            1987        2000              2000       2000
# unique           1923           1                 7         24
# top     -87.724882975          11                 6         15
# freq                3        2000               467        182
#
#        weather_condition lighting_condition       damage  \
# count               2000               2000         2000
# unique                 6                  6            3
# top                CLEAR           DAYLIGHT  OVER $1,500
# freq                1835               1122         1292
#
#                     crash_type injuries_total posted_speed_limit  \
# count                     2000           1994               2000
# unique                       2              5                 12
# top     NO INJURY / DRIVE AWAY              0                 30
# freq                      1376           1707               1455
#
#        prim_contributory_cause
# count                     2000
# unique                      34
# top        UNABLE TO DETERMINE
# freq                       833

# %%
#how many n/a in latitute
geo_df['latitude'].isnull().sum()
# Out:
# 13

# %%
#drop rows where Latitude is N/A
geo_df2 = geo_df[geo_df['latitude'].notna()]
geo_df2.describe()
# Out:
#                                           crash_record_id      latitude  \
# count                                                1987          1987
# unique                                               1987          1923
# top     b2913d087e90f3878667ce448bcc360bac6b630093a012...  41.851654369
# freq                                                    1             3
#
#             longitude crash_month crash_day_of_week crash_hour  \
# count            1987        1987              1987       1987
# unique           1923           1                 7         24
# top     -87.724882975          11                 6         15
# freq                3        1987               465        181
#
#        weather_condition lighting_condition       damage  \
# count               1987               1987         1987
# unique                 6                  6            3
# top                CLEAR           DAYLIGHT  OVER $1,500
# freq                1823               1115         1284
#
#                     crash_type injuries_total posted_speed_limit  \
# count                     1987           1981               1987
# unique                       2              5                 12
# top     NO INJURY / DRIVE AWAY              0                 30
# freq                      1367           1696               1451
#
#        prim_contributory_cause
# count                     1987
# unique                      34
# top        UNABLE TO DETERMINE
# freq                       831

# %%
#grouped just to see how many crashes there were for each hour. 
group_df = geo_df2.groupby(["crash_hour",]).count()
group_df = group_df.sort_values(["crash_hour"], ascending=True)
group_df
# Out:
#             crash_record_id  latitude  longitude  crash_month  \
# crash_hour
# 0                        36        36         36           36
# 1                        34        34         34           34
# 10                      106       106        106          106
# 11                      127       127        127          127
# 12                      122       122        122          122
# 13                      128       128        128          128
# 14                      134       134        134          134
# 15                      181       181        181          181
# 16                      143       143        143          143
# 17                      149       149        149          149
# 18                      118       118        118          118
# 19                      132       132        132          132
# 2                        26        26         26           26
# 20                       91        91         91           91
# 21                       51        51         51           51
# 22                       55        55         55           55
# 23                       75        75         75           75
# 3                        11        11         11           11
# 4                        22        22         22           22
# 5                        24        24         24           24
# 6                        35        35         35           35
# 7                        51        51         51           51
# 8                        63        63         63           63
# 9                        73        73         73           73
#
#             crash_day_of_week  weather_condition  lighting_condition  damage  \
# crash_hour
# 0                          36                 36                  36      36
# 1                          34                 34                  34      34
# 10                        106                106                 106     106
# 11                        127                127                 127     127
# 12                        122                122                 122     122
# 13                        128                128                 128     128
# 14                        134                134                 134     134
# 15                        181                181                 181     181
# 16                        143                143                 143     143
# 17                        149                149                 149     149
# 18                        118                118                 118     118
# 19                        132                132                 132     132
# 2                          26                 26                  26      26
# 20                         91                 91                  91      91
# 21                         51                 51                  51      51
# 22                         55                 55                  55      55
# 23                         75                 75                  75      75
# 3                          11                 11                  11      11
# 4                          22                 22                  22      22
# 5                          24                 24                  24      24
# 6                          35                 35                  35      35
# 7                          51                 51                  51      51
# 8                          63                 63                  63      63
# 9                          73                 73                  73      73
#
#             crash_type  injuries_total  posted_speed_limit  \
# crash_hour
# 0                   36              35                  36
# 1                   34              34                  34
# 10                 106             106                 106
# 11                 127             127                 127
# 12                 122             122                 122
# 13                 128             128                 128
# 14                 134             134                 134
# 15                 181             181                 181
# 16                 143             143                 143
# 17                 149             148                 149
# 18                 118             117                 118
# 19                 132             132                 132
# 2                   26              26                  26
# 20                  91              89                  91
# 21                  51              51                  51
# 22                  55              55                  55
# 23                  75              75                  75
# 3                   11              11                  11
# 4                   22              22                  22
# 5                   24              24                  24
# 6                   35              35                  35
# 7                   51              50                  51
# 8                   63              63                  63
# 9                   73              73                  73
#
#             prim_contributory_cause
# crash_hour
# 0                                36
# 1                                34
# 10                              106
# 11                              127
# 12                              122
# 13                              128
# 14                              134
# 15                              181
# 16                              143
# 17                              149
# 18                              118
# 19                              132
# 2                                26
# 20                               91
# 21                               51
# 22                               55
# 23                               75
# 3                                11
# 4                                22
# 5                                24
# 6                                35
# 7                                51
# 8                                63
# 9                                73

# %%
geo_df2.dtypes
# Out:
# crash_record_id            object
# latitude                   object
# longitude                  object
# crash_month                object
# crash_day_of_week          object
# crash_hour                 object
# weather_condition          object
# lighting_condition         object
# damage                     object
# crash_type                 object
# injuries_total             object
# posted_speed_limit         object
# prim_contributory_cause    object
# dtype: object

# %%
#what are the values in the weather_condition column
geo_df2['weather_condition'].unique()
# Out:
# array(['CLEAR', 'UNKNOWN', 'CLOUDY/OVERCAST', 'RAIN',
#        'SEVERE CROSS WIND GATE', 'OTHER'], dtype=object)

# %%
geo_df2['lighting_condition'].unique()
# Out:
# array(['DARKNESS, LIGHTED ROAD', 'UNKNOWN', 'DARKNESS', 'DUSK', 'DAWN',
#        'DAYLIGHT'], dtype=object)

# %%
geo_df2['damage'].unique()
# Out:
# array(['$500 OR LESS', 'OVER $1,500', '$501 - $1,500'], dtype=object)

# %%
geo_df2['crash_type'].unique()
# Out:
# array(['NO INJURY / DRIVE AWAY', 'INJURY AND / OR TOW DUE TO CRASH'],
#       dtype=object)

# %%
geo_df2['injuries_total'].unique()
# Out:
# array(['0', nan, '1', '2', '3', '4'], dtype=object)

# %%
geo_df2['posted_speed_limit'].unique()
# Out:
# array(['30', '35', '25', '15', '20', '45', '10', '5', '3', '40', '55',
#        '26'], dtype=object)

# %%
geo_df2['prim_contributory_cause'].unique()
# Out:
# array(['DISTRACTION - FROM OUTSIDE VEHICLE',
#        'DRIVING ON WRONG SIDE/WRONG WAY', 'EQUIPMENT - VEHICLE CONDITION',
#        'DISREGARDING TRAFFIC SIGNALS', 'UNABLE TO DETERMINE',
#        'IMPROPER LANE USAGE', 'FOLLOWING TOO CLOSELY', 'IMPROPER BACKING',
#        'FAILING TO YIELD RIGHT-OF-WAY',
#        'FAILING TO REDUCE SPEED TO AVOID CRASH',
#        'IMPROPER OVERTAKING/PASSING',
#        'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE', 'NOT APPLICABLE',
#        'TURNING RIGHT ON RED',
#        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
#        'PHYSICAL CONDITION OF DRIVER', 'IMPROPER TURNING/NO SIGNAL',
#        'DISTRACTION - OTHER ELECTRONIC DEVICE (NAVIGATION DEVICE, DVD PLAYER, ETC.)',
#        'DISTRACTION - FROM INSIDE VEHICLE',
#        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
#        'ROAD CONSTRUCTION/MAINTENANCE', 'DISREGARDING STOP SIGN',
#        'CELL PHONE USE OTHER THAN TEXTING',
#        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
#        'DISREGARDING OTHER TRAFFIC SIGNS', 'WEATHER',
#        'DISREGARDING YIELD SIGN', 'DISREGARDING ROAD MARKINGS',
#        'RELATED TO BUS STOP',
#        'HAD BEEN DRINKING (USE WHEN ARREST IS NOT MADE)',
#        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST', 'ANIMAL',
#        'ROAD ENGINEERING/SURFACE/MARKING DEFECTS', 'TEXTING'],
#       dtype=object)

# %%
geo_df3 =  pd.DataFrame(results_df[['crash_record_id', 'latitude','longitude', 'crash_month', 'crash_day_of_week', 'crash_hour', 'weather_condition', 'lighting_condition', 'damage', 'crash_type', 'injuries_total', 'posted_speed_limit']])
geo_df.head(10)
# Out:
#                                      crash_record_id      latitude  \
# 0  7a5aa591c320dcaa50ee5ff9d0eedb9e423a1f1efa1e4c...  41.734652174
# 1  d95b7c167abad30dff8f1eb4a4f96dabe098eeb9c18d4b...  41.788311923
# 2  a4b8ed2784f7e2f23339aec7b3480aa27c300a77629a44...  41.764817753
# 3  d93027425fc325efbeb74de500f9cee5ef1ab4b177fc5d...  41.880880323
# 4  db0c556175dbae5d290139b69d461480dcdcc3003b8cdd...  41.699547415
# 5  ba5c3b73f593635bd96dae4e93d2a46b3ecf6414974a0d...   41.80247042
# 6  2ea4960b7f03e1928d7cb50a836bb998a3207ae354f861...  41.896804972
# 7  dd755b68a258cd049b7a63ba3b1cd3938e1a6123851de2...   41.77557861
# 8  07bc8ee01e3b260016d0de2898fab86daa65f1632e85c8...  41.878984407
# 9  36460c408759f2674ee74c9d652973b35c23543f8f518d...  41.817224158
#
#        longitude crash_month crash_day_of_week crash_hour weather_condition  \
# 0  -87.637350523          11                 7          2             CLEAR
# 1  -87.671862047          11                 7          1             CLEAR
# 2  -87.662458484          11                 7          1             CLEAR
# 3  -87.666940386          11                 7          0             CLEAR
# 4  -87.642751915          11                 7          0             CLEAR
# 5  -87.581777928          11                 6         23           UNKNOWN
# 6  -87.617027423          11                 6         22             CLEAR
# 7  -87.675171024          11                 6         22             CLEAR
# 8  -87.725183053          11                 6         20             CLEAR
# 9  -87.624526546          11                 6         20             CLEAR
#
#        lighting_condition        damage                        crash_type  \
# 0  DARKNESS, LIGHTED ROAD  $500 OR LESS            NO INJURY / DRIVE AWAY
# 1  DARKNESS, LIGHTED ROAD   OVER $1,500            NO INJURY / DRIVE AWAY
# 2  DARKNESS, LIGHTED ROAD   OVER $1,500            NO INJURY / DRIVE AWAY
# 3  DARKNESS, LIGHTED ROAD   OVER $1,500  INJURY AND / OR TOW DUE TO CRASH
# 4  DARKNESS, LIGHTED ROAD   OVER $1,500            NO INJURY / DRIVE AWAY
# 5                 UNKNOWN   OVER $1,500            NO INJURY / DRIVE AWAY
# 6  DARKNESS, LIGHTED ROAD  $500 OR LESS            NO INJURY / DRIVE AWAY
# 7  DARKNESS, LIGHTED ROAD   OVER $1,500            NO INJURY / DRIVE AWAY
# 8  DARKNESS, LIGHTED ROAD   OVER $1,500  INJURY AND / OR TOW DUE TO CRASH
# 9  DARKNESS, LIGHTED ROAD   OVER $1,500            NO INJURY / DRIVE AWAY
#
#   injuries_total posted_speed_limit             prim_contributory_cause
# 0              0                 30  DISTRACTION - FROM OUTSIDE VEHICLE
# 1              0                 30     DRIVING ON WRONG SIDE/WRONG WAY
# 2              0                 30       EQUIPMENT - VEHICLE CONDITION
# 3            NaN                 30        DISREGARDING TRAFFIC SIGNALS
# 4              0                 35        DISREGARDING TRAFFIC SIGNALS
# 5              0                 30                 UNABLE TO DETERMINE
# 6              0                 35       EQUIPMENT - VEHICLE CONDITION
# 7              0                 30                 UNABLE TO DETERMINE
# 8              0                 25                 UNABLE TO DETERMINE
# 9              0                 30                 IMPROPER LANE USAGE

# %%
#Change data to a corresponding number
geo_df3['crash_type'] = geo_df3['crash_type'].replace(['INJURY AND / OR TOW DUE TO CRASH'],1)
geo_df3['crash_type'] = geo_df3['crash_type'].replace(['NO INJURY / DRIVE AWAY'],2)
geo_df3['damage'] = geo_df3['damage'].replace(['OVER $1,500'],1)
geo_df3['damage'] = geo_df3['damage'].replace(['$501 - $1,500'],2)
geo_df3['damage'] = geo_df3['damage'].replace(['$500 OR LESS'],3)
geo_df3['lighting_condition'] = geo_df3['lighting_condition'].replace(['DAYLIGHT'],1)
geo_df3['lighting_condition'] = geo_df3['lighting_condition'].replace(['LIGHTED ROAD'],2)
geo_df3['lighting_condition'] = geo_df3['lighting_condition'].replace(['DARKNESS, LIGHTED ROAD'],3)
geo_df3['lighting_condition'] = geo_df3['lighting_condition'].replace(['DUSK'],4)
geo_df3['lighting_condition'] = geo_df3['lighting_condition'].replace(['DAWN'],5)
geo_df3['lighting_condition'] = geo_df3['lighting_condition'].replace(['UNKNOWN'],6)
geo_df3['lighting_condition'] = geo_df3['lighting_condition'].replace(['DARKNESS'],7)
geo_df3['weather_condition'] = geo_df3['weather_condition'].replace(['CLEAR'],1)
geo_df3['weather_condition'] = geo_df3['weather_condition'].replace(['RAIN'],2)
geo_df3['weather_condition'] = geo_df3['weather_condition'].replace(['UNKNOWN'],3)
geo_df3['weather_condition'] = geo_df3['weather_condition'].replace(['CLOUDY/OVERCAST'],4)
geo_df3['weather_condition'] = geo_df3['weather_condition'].replace(['OTHER'],5)
geo_df3['weather_condition'] = geo_df3['weather_condition'].replace(['UNKNOWN'],6)
geo_df3['weather_condition'] = geo_df3['weather_condition'].replace(['SNOW'],7)
geo_df3
# Out:
#                                         crash_record_id      latitude  \
# 0     7a5aa591c320dcaa50ee5ff9d0eedb9e423a1f1efa1e4c...  41.734652174
# 1     d95b7c167abad30dff8f1eb4a4f96dabe098eeb9c18d4b...  41.788311923
# 2     a4b8ed2784f7e2f23339aec7b3480aa27c300a77629a44...  41.764817753
# 3     d93027425fc325efbeb74de500f9cee5ef1ab4b177fc5d...  41.880880323
# 4     db0c556175dbae5d290139b69d461480dcdcc3003b8cdd...  41.699547415
# ...                                                 ...           ...
# 1995  6a04c9d28679ca0d0a46433b13f2d56d17dfe494ff1d76...  41.714789649
# 1996  84ab7d75100ed131c587bc98fdc473a7ade2257a9c9bb5...  41.931507483
# 1997  92bf7440a7ee3b4ab76736ab33e9917a61aa39e9f89c39...  41.975230261
# 1998  d8481445cafd272438c252b9a110efa6f538fdd416cb63...  41.864762947
# 1999  e46b559ddfe47c61ab14bd7ff0161c3977122cdffd8b0d...  41.851760374
#
#           longitude crash_month crash_day_of_week crash_hour  \
# 0     -87.637350523          11                 7          2
# 1     -87.671862047          11                 7          1
# 2     -87.662458484          11                 7          1
# 3     -87.666940386          11                 7          0
# 4     -87.642751915          11                 7          0
# ...             ...         ...               ...        ...
# 1995  -87.643173076          11                 4         19
# 1996  -87.756545646          11                 4         19
# 1997   -87.74805446          11                 4         19
# 1998  -87.683686393          11                 4         19
# 1999  -87.716160361          11                 4         19
#
#      weather_condition  lighting_condition  damage  crash_type injuries_total  \
# 0                    1                   3       3           2              0
# 1                    1                   3       1           2              0
# 2                    1                   3       1           2              0
# 3                    1                   3       1           1            NaN
# 4                    1                   3       1           2              0
# ...                ...                 ...     ...         ...            ...
# 1995                 1                   1       1           2              0
# 1996                 1                   7       2           2              0
# 1997                 1                   3       2           2              0
# 1998                 1                   3       1           1              1
# 1999                 1                   5       1           2              0
#
#      posted_speed_limit
# 0                    30
# 1                    30
# 2                    30
# 3                    30
# 4                    35
# ...                 ...
# 1995                 30
# 1996                 30
# 1997                 30
# 1998                 30
# 1999                 30
#
# [2000 rows x 12 columns]

# %%
geo_df3.dtypes
# Out:
# crash_record_id       object
# latitude              object
# longitude             object
# crash_month           object
# crash_day_of_week     object
# crash_hour            object
# weather_condition     object
# lighting_condition     int64
# damage                 int64
# crash_type             int64
# injuries_total        object
# posted_speed_limit    object
# dtype: object

# %%
#changed the data type to see if there were any corrolations
geo_df3["crash_hour"] = geo_df3["crash_hour"].astype(int)
geo_df3["crash_day_of_week"] = geo_df3["crash_day_of_week"].astype(int)
geo_df3["crash_month"] = geo_df3["crash_month"].astype(int)
geo_df3["posted_speed_limit"] = geo_df3["posted_speed_limit"].astype(int)

# %%
geo_df3.corr()
# Out:
#                     crash_month  crash_day_of_week  crash_hour  \
# crash_month                 NaN                NaN         NaN
# crash_day_of_week           NaN           1.000000    0.039272
# crash_hour                  NaN           0.039272    1.000000
# lighting_condition          NaN          -0.020050    0.246728
# damage                      NaN           0.014899    0.005327
# crash_type                  NaN           0.031471   -0.016442
# posted_speed_limit          NaN           0.032132   -0.004201
#
#                     lighting_condition    damage  crash_type  \
# crash_month                        NaN       NaN         NaN
# crash_day_of_week            -0.020050  0.014899    0.031471
# crash_hour                    0.246728  0.005327   -0.016442
# lighting_condition            1.000000 -0.036387   -0.057446
# damage                       -0.036387  1.000000    0.230604
# crash_type                   -0.057446  0.230604    1.000000
# posted_speed_limit            0.000705 -0.042260   -0.132842
#
#                     posted_speed_limit
# crash_month                        NaN
# crash_day_of_week             0.032132
# crash_hour                   -0.004201
# lighting_condition            0.000705
# damage                       -0.042260
# crash_type                   -0.132842
# posted_speed_limit            1.000000

# %%
geo_df3.dtypes
# Out:
# crash_record_id       object
# latitude              object
# longitude             object
# crash_month            int32
# crash_day_of_week      int32
# crash_hour             int32
# weather_condition     object
# lighting_condition     int64
# damage                 int64
# crash_type             int64
# injuries_total        object
# posted_speed_limit     int32
# dtype: object

# %%
#change the data types for the entrie set back to a string. Couldn't get Kmeans to work with mixed data types.
geo_df3 = geo_df3.applymap(str)
geo_df3.dtypes
# Out:
# crash_record_id       object
# latitude              object
# longitude             object
# crash_month           object
# crash_day_of_week     object
# crash_hour            object
# weather_condition     object
# lighting_condition    object
# damage                object
# crash_type            object
# injuries_total        object
# posted_speed_limit    object
# dtype: object

# %%
# Drop null coordinates (one more time)
geo_df3.dropna(axis=0,how='any',subset=['latitude','longitude'],inplace=True)

# %%
K_clusters = range(1,10)
kmeans = [KMeans(n_clusters=i) for i in K_clusters]
Y_axis = geo_df[['latitude']]
X_axis = geo_df[['longitude']]
score = [kmeans[i].fit(Y_axis).score(Y_axis) for i in range(len(kmeans))]
# Visualize
plt.plot(K_clusters, score)
plt.xlabel('Number of Clusters')
plt.ylabel('Score')
plt.title('Elbow Curve')
plt.show()

# %%
# Variable with the Longitude and Latitude
X=geo_df.loc[:,['crash_record_id','latitude','longitude']]
X.head(10)
# Out:
#                                      crash_record_id      latitude  \
# 0  7a5aa591c320dcaa50ee5ff9d0eedb9e423a1f1efa1e4c...  41.734652174
# 1  d95b7c167abad30dff8f1eb4a4f96dabe098eeb9c18d4b...  41.788311923
# 2  a4b8ed2784f7e2f23339aec7b3480aa27c300a77629a44...  41.764817753
# 3  d93027425fc325efbeb74de500f9cee5ef1ab4b177fc5d...  41.880880323
# 4  db0c556175dbae5d290139b69d461480dcdcc3003b8cdd...  41.699547415
# 5  ba5c3b73f593635bd96dae4e93d2a46b3ecf6414974a0d...   41.80247042
# 6  2ea4960b7f03e1928d7cb50a836bb998a3207ae354f861...  41.896804972
# 7  dd755b68a258cd049b7a63ba3b1cd3938e1a6123851de2...   41.77557861
# 8  07bc8ee01e3b260016d0de2898fab86daa65f1632e85c8...  41.878984407
# 9  36460c408759f2674ee74c9d652973b35c23543f8f518d...  41.817224158
#
#        longitude
# 0  -87.637350523
# 1  -87.671862047
# 2  -87.662458484
# 3  -87.666940386
# 4  -87.642751915
# 5  -87.581777928
# 6  -87.617027423
# 7  -87.675171024
# 8  -87.725183053
# 9  -87.624526546

# %%
kmeans = KMeans(n_clusters = 6, init ='k-means++')
kmeans.fit(X[X.columns[1:3]]) # Compute k-means clustering.
X['cluster_label'] = kmeans.fit_predict(X[X.columns[1:3]])
centers = kmeans.cluster_centers_ # Coordinates of cluster centers.
labels = kmeans.predict(X[X.columns[1:3]]) # Labels of each point
X.head(10)
# Out:
#                                      crash_record_id      latitude  \
# 0  7a5aa591c320dcaa50ee5ff9d0eedb9e423a1f1efa1e4c...  41.734652174
# 1  d95b7c167abad30dff8f1eb4a4f96dabe098eeb9c18d4b...  41.788311923
# 2  a4b8ed2784f7e2f23339aec7b3480aa27c300a77629a44...  41.764817753
# 3  d93027425fc325efbeb74de500f9cee5ef1ab4b177fc5d...  41.880880323
# 4  db0c556175dbae5d290139b69d461480dcdcc3003b8cdd...  41.699547415
# 5  ba5c3b73f593635bd96dae4e93d2a46b3ecf6414974a0d...   41.80247042
# 6  2ea4960b7f03e1928d7cb50a836bb998a3207ae354f861...  41.896804972
# 7  dd755b68a258cd049b7a63ba3b1cd3938e1a6123851de2...   41.77557861
# 8  07bc8ee01e3b260016d0de2898fab86daa65f1632e85c8...  41.878984407
# 9  36460c408759f2674ee74c9d652973b35c23543f8f518d...  41.817224158
#
#        longitude  cluster_label
# 0  -87.637350523              3
# 1  -87.671862047              2
# 2  -87.662458484              2
# 3  -87.666940386              0
# 4  -87.642751915              3
# 5  -87.581777928              3
# 6  -87.617027423              0
# 7  -87.675171024              2
# 8  -87.725183053              5
# 9  -87.624526546              0

# %%
#X.plot.scatter(x = 'latitude', y = 'longitude', c=labels, s=50, cmap='viridis')
#plt.scatter(centers[:, 0], centers[:, 1], c='black', s=200, alpha=0.5);

# %%
result1 = pd.concat([X, geo_df3], axis=1, join='inner')
result1
# Out:
#                                         crash_record_id      latitude  \
# 0     7a5aa591c320dcaa50ee5ff9d0eedb9e423a1f1efa1e4c...  41.734652174
# 1     d95b7c167abad30dff8f1eb4a4f96dabe098eeb9c18d4b...  41.788311923
# 2     a4b8ed2784f7e2f23339aec7b3480aa27c300a77629a44...  41.764817753
# 3     d93027425fc325efbeb74de500f9cee5ef1ab4b177fc5d...  41.880880323
# 4     db0c556175dbae5d290139b69d461480dcdcc3003b8cdd...  41.699547415
# ...                                                 ...           ...
# 1995  6a04c9d28679ca0d0a46433b13f2d56d17dfe494ff1d76...  41.714789649
# 1996  84ab7d75100ed131c587bc98fdc473a7ade2257a9c9bb5...  41.931507483
# 1997  92bf7440a7ee3b4ab76736ab33e9917a61aa39e9f89c39...  41.975230261
# 1998  d8481445cafd272438c252b9a110efa6f538fdd416cb63...  41.864762947
# 1999  e46b559ddfe47c61ab14bd7ff0161c3977122cdffd8b0d...  41.851760374
#
#           longitude  cluster_label  \
# 0     -87.637350523              3
# 1     -87.671862047              2
# 2     -87.662458484              2
# 3     -87.666940386              0
# 4     -87.642751915              3
# ...             ...            ...
# 1995  -87.643173076              3
# 1996  -87.756545646              1
# 1997   -87.74805446              1
# 1998  -87.683686393              0
# 1999  -87.716160361              5
#
#                                         crash_record_id      latitude  \
# 0     7a5aa591c320dcaa50ee5ff9d0eedb9e423a1f1efa1e4c...  41.734652174
# 1     d95b7c167abad30dff8f1eb4a4f96dabe098eeb9c18d4b...  41.788311923
# 2     a4b8ed2784f7e2f23339aec7b3480aa27c300a77629a44...  41.764817753
# 3     d93027425fc325efbeb74de500f9cee5ef1ab4b177fc5d...  41.880880323
# 4     db0c556175dbae5d290139b69d461480dcdcc3003b8cdd...  41.699547415
# ...                                                 ...           ...
# 1995  6a04c9d28679ca0d0a46433b13f2d56d17dfe494ff1d76...  41.714789649
# 1996  84ab7d75100ed131c587bc98fdc473a7ade2257a9c9bb5...  41.931507483
# 1997  92bf7440a7ee3b4ab76736ab33e9917a61aa39e9f89c39...  41.975230261
# 1998  d8481445cafd272438c252b9a110efa6f538fdd416cb63...  41.864762947
# 1999  e46b559ddfe47c61ab14bd7ff0161c3977122cdffd8b0d...  41.851760374
#
#           longitude crash_month crash_day_of_week crash_hour  \
# 0     -87.637350523          11                 7          2
# 1     -87.671862047          11                 7          1
# 2     -87.662458484          11                 7          1
# 3     -87.666940386          11                 7          0
# 4     -87.642751915          11                 7          0
# ...             ...         ...               ...        ...
# 1995  -87.643173076          11                 4         19
# 1996  -87.756545646          11                 4         19
# 1997   -87.74805446          11                 4         19
# 1998  -87.683686393          11                 4         19
# 1999  -87.716160361          11                 4         19
#
#      weather_condition lighting_condition damage crash_type injuries_total  \
# 0                    1                  3      3          2              0
# 1                    1                  3      1          2              0
# 2                    1                  3      1          2              0
# 3                    1                  3      1          1            nan
# 4                    1                  3      1          2              0
# ...                ...                ...    ...        ...            ...
# 1995                 1                  1      1          2              0
# 1996                 1                  7      2          2              0
# 1997                 1                  3      2          2              0
# 1998                 1                  3      1          1              1
# 1999                 1                  5      1          2              0
#
#      posted_speed_limit
# 0                    30
# 1                    30
# 2                    30
# 3                    30
# 4                    35
# ...                 ...
# 1995                 30
# 1996                 30
# 1997                 30
# 1998                 30
# 1999                 30
#
# [1987 rows x 16 columns]

# %%
result1.dtypes
# Out:
# crash_record_id       object
# latitude              object
# longitude             object
# cluster_label          int32
# crash_record_id       object
# latitude              object
# longitude             object
# crash_month           object
# crash_day_of_week     object
# crash_hour            object
# weather_condition     object
# lighting_condition    object
# damage                object
# crash_type            object
# injuries_total        object
# posted_speed_limit    object
# dtype: object

# %%
result2 =  pd.DataFrame(result1[['crash_record_id', 'latitude','longitude', 'crash_month', 'crash_day_of_week', 'crash_hour', 'weather_condition', 'lighting_condition', 'damage', 'crash_type', 'injuries_total', 'posted_speed_limit', 'cluster_label']])
result2.head(10)
# Out:
#                                      crash_record_id  \
# 0  7a5aa591c320dcaa50ee5ff9d0eedb9e423a1f1efa1e4c...
# 1  d95b7c167abad30dff8f1eb4a4f96dabe098eeb9c18d4b...
# 2  a4b8ed2784f7e2f23339aec7b3480aa27c300a77629a44...
# 3  d93027425fc325efbeb74de500f9cee5ef1ab4b177fc5d...
# 4  db0c556175dbae5d290139b69d461480dcdcc3003b8cdd...
# 5  ba5c3b73f593635bd96dae4e93d2a46b3ecf6414974a0d...
# 6  2ea4960b7f03e1928d7cb50a836bb998a3207ae354f861...
# 7  dd755b68a258cd049b7a63ba3b1cd3938e1a6123851de2...
# 8  07bc8ee01e3b260016d0de2898fab86daa65f1632e85c8...
# 9  36460c408759f2674ee74c9d652973b35c23543f8f518d...
#
#                                      crash_record_id      latitude  \
# 0  7a5aa591c320dcaa50ee5ff9d0eedb9e423a1f1efa1e4c...  41.734652174
# 1  d95b7c167abad30dff8f1eb4a4f96dabe098eeb9c18d4b...  41.788311923
# 2  a4b8ed2784f7e2f23339aec7b3480aa27c300a77629a44...  41.764817753
# 3  d93027425fc325efbeb74de500f9cee5ef1ab4b177fc5d...  41.880880323
# 4  db0c556175dbae5d290139b69d461480dcdcc3003b8cdd...  41.699547415
# 5  ba5c3b73f593635bd96dae4e93d2a46b3ecf6414974a0d...   41.80247042
# 6  2ea4960b7f03e1928d7cb50a836bb998a3207ae354f861...  41.896804972
# 7  dd755b68a258cd049b7a63ba3b1cd3938e1a6123851de2...   41.77557861
# 8  07bc8ee01e3b260016d0de2898fab86daa65f1632e85c8...  41.878984407
# 9  36460c408759f2674ee74c9d652973b35c23543f8f518d...  41.817224158
#
#        latitude      longitude      longitude crash_month crash_day_of_week  \
# 0  41.734652174  -87.637350523  -87.637350523          11                 7
# 1  41.788311923  -87.671862047  -87.671862047          11                 7
# 2  41.764817753  -87.662458484  -87.662458484          11                 7
# 3  41.880880323  -87.666940386  -87.666940386          11                 7
# 4  41.699547415  -87.642751915  -87.642751915          11                 7
# 5   41.80247042  -87.581777928  -87.581777928          11                 6
# 6  41.896804972  -87.617027423  -87.617027423          11                 6
# 7   41.77557861  -87.675171024  -87.675171024          11                 6
# 8  41.878984407  -87.725183053  -87.725183053          11                 6
# 9  41.817224158  -87.624526546  -87.624526546          11                 6
#
#   crash_hour weather_condition lighting_condition damage crash_type  \
# 0          2                 1                  3      3          2
# 1          1                 1                  3      1          2
# 2          1                 1                  3      1          2
# 3          0                 1                  3      1          1
# 4          0                 1                  3      1          2
# 5         23                 3                  6      1          2
# 6         22                 1                  3      3          2
# 7         22                 1                  3      1          2
# 8         20                 1                  3      1          1
# 9         20                 1                  3      1          2
#
#   injuries_total posted_speed_limit  cluster_label
# 0              0                 30              3
# 1              0                 30              2
# 2              0                 30              2
# 3            nan                 30              0
# 4              0                 35              3
# 5              0                 30              3
# 6              0                 35              0
# 7              0                 30              2
# 8              0                 25              5
# 9              0                 30              0

# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, time
from sklearn.cluster import DBSCAN
from sklearn import metrics
from geopy.distance import great_circle
from shapely.geometry import MultiPoint
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-30-ac73a51d6acb> in <module>
#       3 from sklearn import metrics
#       4 from geopy.distance import great_circle
# ----> 5 from shapely.geometry import MultiPoint
#
# ~\Anaconda3\lib\site-packages\shapely\geometry\__init__.py in <module>
#       2 """
#       3
# ----> 4 from .base import CAP_STYLE, JOIN_STYLE
#       5 from .geo import box, shape, asShape, mapping
#       6 from .point import Point, asPoint
#
# ~\Anaconda3\lib\site-packages\shapely\geometry\base.py in <module>
#      17
#      18 from shapely.affinity import affine_transform
# ---> 19 from shapely.coords import CoordinateSequence
#      20 from shapely.errors import WKBReadingError, WKTReadingError
#      21 from shapely.geos import WKBWriter, WKTWriter
#
# ~\Anaconda3\lib\site-packages\shapely\coords.py in <module>
#       6 from ctypes import byref, c_double, c_uint
#       7
# ----> 8 from shapely.geos import lgeos
#       9 from shapely.topology import Validating
#      10
#
# ~\Anaconda3\lib\site-packages\shapely\geos.py in <module>
#     152     if os.getenv('CONDA_PREFIX', ''):
#     153         # conda package.
# --> 154         _lgeos = CDLL(os.path.join(sys.prefix, 'Library', 'bin', 'geos_c.dll'))
#     155     else:
#     156         try:
#
# ~\Anaconda3\lib\ctypes\__init__.py in __init__(self, name, mode, handle, use_errno, use_last_error)
#     362
#     363         if handle is None:
# --> 364             self._handle = _dlopen(self._name, mode)
#     365         else:
#     366             self._handle = handle
#
# OSError: [WinError 126] The specified module could not be found

# %%
# define the number of kilometers in one radian
kms_per_radian = 6371.0088

# %%
# represent points consistently as (lat, lon)
coords = pd.DataFrame(geo_df[['latitude', 'longitude']])
coords.rename(columns={'latitude': 'lat', 'longitude': 'lon'}, inplace=True)
coords
# Out:
#                lat            lon
# 0     42.021974905  -87.666969524
# 1     41.778151035  -87.722600136
# 2     41.885653668  -87.774688353
# 3     41.913631723  -87.730258725
# 4     41.761112759   -87.64930616
# ...            ...            ...
# 1995  41.922182525   -87.69539385
# 1996  41.865752299  -87.761792881
# 1997    41.9024425  -87.733879652
# 1998  41.941850434  -87.654226407
# 1999  41.760645421  -87.572620551
#
# [1987 rows x 2 columns]

# %%
# Need to change object type to float type for the calculations
coords["lat"] = pd.to_numeric(coords["lat"], downcast="float")
coords["lon"] = pd.to_numeric(coords["lon"], downcast="float")
coords.dtypes
# Out:
# lat    float32
# lon    float32
# dtype: object

# %%
# define epsilon as 1.5 kilometers, converted to radians for use by haversine
epsilon = 1.5 / kms_per_radian

# %%
start_time = time.time()
db = DBSCAN(eps=epsilon, min_samples=1, algorithm='ball_tree', metric='haversine').fit(np.radians(coords))
cluster_labels = db.labels_

# get the number of clusters
num_clusters = len(set(cluster_labels))

# all done, print the outcome
message = 'Clustered {:,} points down to {:,} clusters, for {:.1f}% compression in {:,.2f} seconds'
print(message.format(len(geo_df), num_clusters, 100*(1 - float(num_clusters) / len(geo_df)), time.time()-start_time))
print('Silhouette coefficient: {:0.03f}'.format(metrics.silhouette_score(coords, cluster_labels)))
# Out:
# Clustered 1,987 points down to 10 clusters, for 99.5% compression in 0.15 seconds
# Silhouette coefficient: -0.173

# %%
coords.dtypes
# Out:
# lat    float32
# lon    float32
# dtype: object

# %%
# turn the clusters in to a pandas series, where each element is a cluster of points
clusters = pd.Series([coords[cluster_labels==n] for n in range(num_clusters)])
clusters.dtypes
clusters
# Out:
# 0                lat        lon
# 0     42.021976 -87...
# 1              lat        lon
# 13  41.651703 -87.527...
# 2                lat        lon
# 37    41.751980 -87...
# 3                lat        lon
# 56    41.666725 -87...
# 4               lat        lon
# 265  41.684498 -87.5...
# 5                 lat      lon
# 419  41.953766 -87.9142
# 6               lat        lon
# 609  41.713062 -87.7...
# 7                lat        lon
# 764   41.979534 -87...
# 8                lat        lon
# 1238  41.690773 -87...
# 9                lat       lon
# 1485  41.980686 -87....
# dtype: object

# %%
print(num_clusters)
# Out:
# 10

# %%
def get_centermost_point(cluster):
    centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
    centermost_point = min(cluster, key=lambda point: great_circle(point, centroid).m)
    return tuple(centermost_point)

centermost_points = clusters.apply(get_centermost_point)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-40-fb3bc6c7d829> in <module>
#       4     return tuple(centermost_point)
#       5
# ----> 6 centermost_points = clusters.apply(get_centermost_point)
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in apply(self, func, convert_dtype, args, **kwds)
#    3846             else:
#    3847                 values = self.astype(object).values
# -> 3848                 mapped = lib.map_infer(values, f, convert=convert_dtype)
#    3849
#    3850         if len(mapped) and isinstance(mapped[0], Series):
#
# pandas\_libs\lib.pyx in pandas._libs.lib.map_infer()
#
# <ipython-input-40-fb3bc6c7d829> in get_centermost_point(cluster)
#       1 def get_centermost_point(cluster):
# ----> 2     centroid = (MultiPoint(cluster).centroid.x, MultiPoint(cluster).centroid.y)
#       3     centermost_point = min(cluster, key=lambda point: great_circle(point, centroid).m)
#       4     return tuple(centermost_point)
#       5
#
# NameError: name 'MultiPoint' is not defined

# %%
# centroid = (MultiPoint(clusters[2]).centroid.x, MultiPoint(clusters[2]).centroid.y)
# centermost_point = min(clusters, key=lambda point: great_circle(point, centroid).m)

# %%
# unzip the list of centermost points (lat, lon) tuples into separate lat and lon lists
lats, lons = zip(*centermost_points)

# from these lats/lons create a new df of one representative point for each cluster
rep_points = pd.DataFrame({'lon':lons, 'lat':lats})
rep_points.tail()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-54c3dfbd6316> in <module>
#       1 # unzip the list of centermost points (lat, lon) tuples into separate lat and lon lists
# ----> 2 lats, lons = zip(*centermost_points)
#       3
#       4 # from these lats/lons create a new df of one representative point for each cluster
#       5 rep_points = pd.DataFrame({'lon':lons, 'lat':lats})
#
# NameError: name 'centermost_points' is not defined

# %%
# plot the final reduced set of coordinate points vs the original full set
fig, ax = plt.subplots(figsize=[10, 6])
rs_scatter = ax.scatter(rs['lon'], rs['lat'], c='#99cc99', edgecolor='None', alpha=0.7, s=120)
df_scatter = ax.scatter(geo_df['lon'], geo_df['lat'], c='k', alpha=0.9, s=3)
ax.set_title('Full data set vs DBSCAN reduced set')
ax.set_xlabel('Longitude')
ax.set_ylabel('Latitude')
ax.legend([geo_df_scatter, rs_scatter], ['Full set', 'Reduced set'], loc='upper right')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-43-dd8d6bc4cc60> in <module>
#       1 # plot the final reduced set of coordinate points vs the original full set
#       2 fig, ax = plt.subplots(figsize=[10, 6])
# ----> 3 rs_scatter = ax.scatter(rs['lon'], rs['lat'], c='#99cc99', edgecolor='None', alpha=0.7, s=120)
#       4 df_scatter = ax.scatter(geo_df['lon'], geo_df['lat'], c='k', alpha=0.9, s=3)
#       5 ax.set_title('Full data set vs DBSCAN reduced set')
#
# NameError: name 'rs' is not defined
